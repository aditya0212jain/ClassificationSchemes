# %%
import numpy as np
import scipy
from scipy.stats import norm
import math
import random
import operator

# %%
class knn:
    """kNearest Neighbour classification implementation"""
    
    def __init__(self,k):
        self.k = k
        
    def euclideanDistance(self,data1,data2,n):
        distance = 0
        for i in range(0,n):
            distance+=np.square(data1[i]-data2[i])
        return np.sqrt(distance)
    
    def manhattanDistance(self,data1,data2,n):
        distance = 0
        for i in range(n):
            distance+=abs(data1[i]-data2[i])
        return distance
    
    def hammingDistance(self,data1,data2,n):
        distance = 0
        for i in range(n):
            if data1[i]==data2[i]:
                distance+=1
        return distance
    
    ##using euclidean distance for now
    def getNeighbours(self,dataset,data):
        distances = []
        length = len(data)
#         print("length:"+str(length))
        for i in range(0,len(dataset)):
            ##change the below line for different distances
#             print("i in neighbour: "+str(i))
            dist = self.euclideanDistance(data,dataset[i],length)
            distances.append((dataset[i],dist))
        distances.sort(key=operator.itemgetter(1))
        neighbours = []
        for i in range(self.k):
            neighbours.append(distances[i][0])
        return neighbours
    
    def getClass(self,neighbours):
        classOccurrence = {}
        for i in range(len(neighbours)):
            t = neighbours[i][-1]
            if t in classOccurrence:
                classOccurrence[t]+=1
            else:
                classOccurrence[t] = 1
        sortedOccurrence = sorted(classOccurrence.items(),key=operator.itemgetter(1),reverse=True)
        return sortedOccurrence[0][0]

# %%
import os
import sys

# %%
scriptpath = "./fashion-mnist/utils"

# Add the directory containing your module to the Python path (wants absolute paths)
sys.path.append(os.path.abspath(scriptpath))

# %%
import mnist_reader

# %%
X_train, Y_train = mnist_reader.load_mnist('./fashion-mnist/data/fashion', kind='train')
X_test, Y_test = mnist_reader.load_mnist('./fashion-mnist/data/fashion', kind='t10k')

# %%
print(X_test.shape)
print(Y_test.shape)
print(X_train.shape)
print(Y_train.shape)
# Out:
# (10000, 784)
# (10000,)
# (60000, 784)
# (60000,)

# %%
# print(Y_test[0])
b = np.ones((X_train.shape[0],1))
x = np.hstack((X_train,b))
for i in range(X_train.shape[0]):
    x[i][X_train.shape[1]]=Y_train[i]

# %%
class PCA:
    def __init__(self,m):
        self.m = m
        
    def dimensionReduction(self,data):
        # data is of the form n X d , with d dimensions
        self.d = data.shape[1]
        self.n = data.shape[0]
        #data -= np.mean(data,axis=0)
        S = np.cov(data.T)
#         print(S.shape)
        w,v = np.linalg.eig(S)
        #w is the array of eigen values and v's are the corresponding eigen vectors
        # for w[i] -> v[:,i] is the corresponding eigen vectors
        tempList = []
        for i in range(self.d):
            tempList.append((w[i],i))
        tempList.sort(reverse=True)
        tempVecList = []
        for i in range(self.m):
            tempVecList.append(v[:,tempList[i][1]])
        finalVecMat = np.array(tempVecList) # m X d
        reducedMat = np.matmul(finalVecMat,data.T) # m X n
        return reducedMat.T # n X m , dimension reduced from d -> m

# %%
k=2
while k!=-1:
    pcaObj = PCA(k)
    reducedTrain = pcaObj.dimensionReduction(X_train)
    reducedTest = pcaObj.dimensionReduction(X_test)
    
    b = np.ones((reducedTrain.shape[0],1))
    x = np.hstack((reducedTrain,b))
    for i in range(reducedTrain.shape[0]):
        x[i][reducedTrain.shape[1]]=Y_train[i]
    
    j=2
    while j!=-1:
        obj = knn(j)
        count=0
        limit =1000
        if k>200:
            limit = 500
        for i in range(limit+1):
            nei = obj.getNeighbours(x,reducedTest[i])
            ans = obj.getClass(nei)
#             print("our ans: "+str(ans)+" ,original ans:"+str(Y_test[i])+" for i:"+str(i))
            if ans != Y_test[i]:
                count+=1
#             print(i)
#             print(count)
            if i%10==0:
                print("pca(m): "+str(k)+",k: "+str(j)+",count: "+str(count)+",i:"+str(i))
        print("pca(m): "+str(k)+",k: "+str(j)+",count: "+str(count))
        if j==2:
            j=100
        elif j==100:
            j=1000
        else:
            j=-1
    if k==512:
        k=700
    elif k==700:
        k=-1
    elif k==2:
        k=50
    elif k==50:
        k=150
    elif k==150:
        k=512
# Out:
# pca(m): 2,k: 2,count: 1,i:0
# pca(m): 2,k: 2,count: 6,i:10
# pca(m): 2,k: 2,count: 9,i:20
# pca(m): 2,k: 2,count: 14,i:30
# pca(m): 2,k: 2,count: 19,i:40
# pca(m): 2,k: 2,count: 27,i:50
# pca(m): 2,k: 2,count: 31,i:60
# pca(m): 2,k: 2,count: 35,i:70
# pca(m): 2,k: 2,count: 40,i:80
# pca(m): 2,k: 2,count: 43,i:90
# pca(m): 2,k: 2,count: 48,i:100
# pca(m): 2,k: 2,count: 55,i:110
# pca(m): 2,k: 2,count: 59,i:120
# pca(m): 2,k: 2,count: 62,i:130
# pca(m): 2,k: 2,count: 67,i:140
# pca(m): 2,k: 2,count: 72,i:150
# pca(m): 2,k: 2,count: 79,i:160
# pca(m): 2,k: 2,count: 85,i:170
# pca(m): 2,k: 2,count: 89,i:180
# pca(m): 2,k: 2,count: 95,i:190
# pca(m): 2,k: 2,count: 98,i:200
# pca(m): 2,k: 2,count: 106,i:210
# pca(m): 2,k: 2,count: 111,i:220
# pca(m): 2,k: 2,count: 118,i:230
# pca(m): 2,k: 2,count: 121,i:240
# pca(m): 2,k: 2,count: 125,i:250
# pca(m): 2,k: 2,count: 132,i:260
# pca(m): 2,k: 2,count: 140,i:270
# pca(m): 2,k: 2,count: 145,i:280
# pca(m): 2,k: 2,count: 151,i:290
# pca(m): 2,k: 2,count: 158,i:300
# pca(m): 2,k: 2,count: 162,i:310
# pca(m): 2,k: 2,count: 169,i:320
# pca(m): 2,k: 2,count: 176,i:330
# pca(m): 2,k: 2,count: 184,i:340
# pca(m): 2,k: 2,count: 188,i:350
# pca(m): 2,k: 2,count: 192,i:360
# pca(m): 2,k: 2,count: 198,i:370
# pca(m): 2,k: 2,count: 202,i:380
# pca(m): 2,k: 2,count: 207,i:390
# pca(m): 2,k: 2,count: 214,i:400
# pca(m): 2,k: 2,count: 221,i:410
# pca(m): 2,k: 2,count: 223,i:420
# pca(m): 2,k: 2,count: 228,i:430
# pca(m): 2,k: 2,count: 232,i:440
# pca(m): 2,k: 2,count: 237,i:450
# pca(m): 2,k: 2,count: 245,i:460
# pca(m): 2,k: 2,count: 251,i:470
# pca(m): 2,k: 2,count: 257,i:480
# pca(m): 2,k: 2,count: 265,i:490
# pca(m): 2,k: 2,count: 271,i:500
# pca(m): 2,k: 2,count: 276,i:510
# pca(m): 2,k: 2,count: 282,i:520
# pca(m): 2,k: 2,count: 287,i:530
# pca(m): 2,k: 2,count: 293,i:540
# pca(m): 2,k: 2,count: 299,i:550
# pca(m): 2,k: 2,count: 303,i:560
# pca(m): 2,k: 2,count: 307,i:570
# pca(m): 2,k: 2,count: 314,i:580
# pca(m): 2,k: 2,count: 319,i:590
# pca(m): 2,k: 2,count: 325,i:600
# pca(m): 2,k: 2,count: 332,i:610
# pca(m): 2,k: 2,count: 337,i:620
# pca(m): 2,k: 2,count: 345,i:630
# pca(m): 2,k: 2,count: 354,i:640
# pca(m): 2,k: 2,count: 358,i:650
# pca(m): 2,k: 2,count: 364,i:660
# pca(m): 2,k: 2,count: 370,i:670
# pca(m): 2,k: 2,count: 377,i:680
# pca(m): 2,k: 2,count: 384,i:690
# pca(m): 2,k: 2,count: 390,i:700
# pca(m): 2,k: 2,count: 392,i:710
# pca(m): 2,k: 2,count: 398,i:720
# pca(m): 2,k: 2,count: 401,i:730
# pca(m): 2,k: 2,count: 409,i:740
# pca(m): 2,k: 2,count: 416,i:750
# pca(m): 2,k: 2,count: 421,i:760
# pca(m): 2,k: 2,count: 426,i:770
# pca(m): 2,k: 2,count: 432,i:780
# pca(m): 2,k: 2,count: 436,i:790
# pca(m): 2,k: 2,count: 442,i:800
# pca(m): 2,k: 2,count: 447,i:810
# pca(m): 2,k: 2,count: 452,i:820
# pca(m): 2,k: 2,count: 458,i:830
# pca(m): 2,k: 2,count: 463,i:840
# pca(m): 2,k: 2,count: 469,i:850
# pca(m): 2,k: 2,count: 475,i:860
# pca(m): 2,k: 2,count: 476,i:870
# pca(m): 2,k: 2,count: 480,i:880
# pca(m): 2,k: 2,count: 485,i:890
# pca(m): 2,k: 2,count: 491,i:900
# pca(m): 2,k: 2,count: 498,i:910
# pca(m): 2,k: 2,count: 502,i:920
# pca(m): 2,k: 2,count: 508,i:930
# pca(m): 2,k: 2,count: 513,i:940
# pca(m): 2,k: 2,count: 518,i:950
# pca(m): 2,k: 2,count: 525,i:960
# pca(m): 2,k: 2,count: 533,i:970
# pca(m): 2,k: 2,count: 537,i:980
# pca(m): 2,k: 2,count: 545,i:990
# pca(m): 2,k: 2,count: 551,i:1000
# pca(m): 2,k: 2,count: 551
# pca(m): 2,k: 100,count: 1,i:0
# pca(m): 2,k: 100,count: 6,i:10
# pca(m): 2,k: 100,count: 10,i:20
# pca(m): 2,k: 100,count: 16,i:30
# pca(m): 2,k: 100,count: 20,i:40
# pca(m): 2,k: 100,count: 25,i:50
# pca(m): 2,k: 100,count: 30,i:60
# pca(m): 2,k: 100,count: 33,i:70
# pca(m): 2,k: 100,count: 37,i:80
# pca(m): 2,k: 100,count: 41,i:90
# pca(m): 2,k: 100,count: 44,i:100
# pca(m): 2,k: 100,count: 48,i:110
# pca(m): 2,k: 100,count: 49,i:120
# pca(m): 2,k: 100,count: 50,i:130
# pca(m): 2,k: 100,count: 52,i:140
# pca(m): 2,k: 100,count: 57,i:150
# pca(m): 2,k: 100,count: 61,i:160
# pca(m): 2,k: 100,count: 65,i:170
# pca(m): 2,k: 100,count: 67,i:180
# pca(m): 2,k: 100,count: 71,i:190
# pca(m): 2,k: 100,count: 77,i:200
# pca(m): 2,k: 100,count: 81,i:210
# pca(m): 2,k: 100,count: 85,i:220
# pca(m): 2,k: 100,count: 89,i:230
# pca(m): 2,k: 100,count: 93,i:240
# pca(m): 2,k: 100,count: 98,i:250
# pca(m): 2,k: 100,count: 103,i:260
# pca(m): 2,k: 100,count: 109,i:270
# pca(m): 2,k: 100,count: 113,i:280
# pca(m): 2,k: 100,count: 118,i:290
# pca(m): 2,k: 100,count: 123,i:300
# pca(m): 2,k: 100,count: 127,i:310
# pca(m): 2,k: 100,count: 131,i:320
# pca(m): 2,k: 100,count: 135,i:330
# pca(m): 2,k: 100,count: 139,i:340
# pca(m): 2,k: 100,count: 143,i:350
# pca(m): 2,k: 100,count: 148,i:360
# pca(m): 2,k: 100,count: 154,i:370
# pca(m): 2,k: 100,count: 158,i:380
# pca(m): 2,k: 100,count: 162,i:390
# pca(m): 2,k: 100,count: 165,i:400
# pca(m): 2,k: 100,count: 170,i:410
# pca(m): 2,k: 100,count: 174,i:420
# pca(m): 2,k: 100,count: 177,i:430
# pca(m): 2,k: 100,count: 181,i:440
# pca(m): 2,k: 100,count: 187,i:450
# pca(m): 2,k: 100,count: 191,i:460
# pca(m): 2,k: 100,count: 193,i:470
# pca(m): 2,k: 100,count: 201,i:480
# pca(m): 2,k: 100,count: 205,i:490
# pca(m): 2,k: 100,count: 209,i:500
# pca(m): 2,k: 100,count: 212,i:510
# pca(m): 2,k: 100,count: 218,i:520
# pca(m): 2,k: 100,count: 224,i:530
# pca(m): 2,k: 100,count: 230,i:540
# pca(m): 2,k: 100,count: 235,i:550
# pca(m): 2,k: 100,count: 239,i:560
# pca(m): 2,k: 100,count: 246,i:570
# pca(m): 2,k: 100,count: 249,i:580
# pca(m): 2,k: 100,count: 254,i:590
# pca(m): 2,k: 100,count: 261,i:600
# pca(m): 2,k: 100,count: 266,i:610
# pca(m): 2,k: 100,count: 269,i:620
# pca(m): 2,k: 100,count: 275,i:630
# pca(m): 2,k: 100,count: 283,i:640
# pca(m): 2,k: 100,count: 286,i:650
# pca(m): 2,k: 100,count: 290,i:660
# pca(m): 2,k: 100,count: 297,i:670
# pca(m): 2,k: 100,count: 302,i:680
# pca(m): 2,k: 100,count: 310,i:690
# pca(m): 2,k: 100,count: 315,i:700
# pca(m): 2,k: 100,count: 318,i:710
# pca(m): 2,k: 100,count: 322,i:720
# pca(m): 2,k: 100,count: 326,i:730
# pca(m): 2,k: 100,count: 330,i:740
# pca(m): 2,k: 100,count: 334,i:750
# pca(m): 2,k: 100,count: 338,i:760
# pca(m): 2,k: 100,count: 342,i:770
# pca(m): 2,k: 100,count: 348,i:780
# pca(m): 2,k: 100,count: 352,i:790
# pca(m): 2,k: 100,count: 357,i:800
# pca(m): 2,k: 100,count: 362,i:810
# pca(m): 2,k: 100,count: 368,i:820
# pca(m): 2,k: 100,count: 373,i:830
# pca(m): 2,k: 100,count: 378,i:840
# pca(m): 2,k: 100,count: 383,i:850
# pca(m): 2,k: 100,count: 387,i:860
# pca(m): 2,k: 100,count: 388,i:870
# pca(m): 2,k: 100,count: 391,i:880
# pca(m): 2,k: 100,count: 395,i:890
# pca(m): 2,k: 100,count: 400,i:900
# pca(m): 2,k: 100,count: 403,i:910
# pca(m): 2,k: 100,count: 406,i:920
# pca(m): 2,k: 100,count: 413,i:930
# pca(m): 2,k: 100,count: 419,i:940
# pca(m): 2,k: 100,count: 424,i:950
# pca(m): 2,k: 100,count: 429,i:960
# pca(m): 2,k: 100,count: 437,i:970
# pca(m): 2,k: 100,count: 443,i:980
# pca(m): 2,k: 100,count: 452,i:990
# pca(m): 2,k: 100,count: 456,i:1000
# pca(m): 2,k: 100,count: 456
# pca(m): 2,k: 1000,count: 1,i:0
# pca(m): 2,k: 1000,count: 7,i:10
# pca(m): 2,k: 1000,count: 11,i:20
# pca(m): 2,k: 1000,count: 17,i:30
# pca(m): 2,k: 1000,count: 20,i:40
# pca(m): 2,k: 1000,count: 24,i:50
# pca(m): 2,k: 1000,count: 30,i:60
# pca(m): 2,k: 1000,count: 33,i:70
# pca(m): 2,k: 1000,count: 37,i:80
# pca(m): 2,k: 1000,count: 40,i:90
# pca(m): 2,k: 1000,count: 45,i:100
# pca(m): 2,k: 1000,count: 49,i:110
# pca(m): 2,k: 1000,count: 52,i:120
# pca(m): 2,k: 1000,count: 54,i:130
# pca(m): 2,k: 1000,count: 56,i:140
# pca(m): 2,k: 1000,count: 61,i:150
# pca(m): 2,k: 1000,count: 65,i:160
# pca(m): 2,k: 1000,count: 69,i:170
# pca(m): 2,k: 1000,count: 71,i:180
# pca(m): 2,k: 1000,count: 75,i:190
# pca(m): 2,k: 1000,count: 81,i:200
# pca(m): 2,k: 1000,count: 84,i:210
# pca(m): 2,k: 1000,count: 88,i:220
# pca(m): 2,k: 1000,count: 91,i:230
# pca(m): 2,k: 1000,count: 96,i:240
# pca(m): 2,k: 1000,count: 101,i:250
# pca(m): 2,k: 1000,count: 105,i:260
# pca(m): 2,k: 1000,count: 109,i:270
# pca(m): 2,k: 1000,count: 113,i:280
# pca(m): 2,k: 1000,count: 119,i:290
# pca(m): 2,k: 1000,count: 124,i:300
# pca(m): 2,k: 1000,count: 128,i:310
# pca(m): 2,k: 1000,count: 133,i:320
# pca(m): 2,k: 1000,count: 136,i:330
# pca(m): 2,k: 1000,count: 140,i:340
# pca(m): 2,k: 1000,count: 144,i:350
# pca(m): 2,k: 1000,count: 150,i:360
# pca(m): 2,k: 1000,count: 156,i:370
# pca(m): 2,k: 1000,count: 160,i:380
# pca(m): 2,k: 1000,count: 165,i:390
# pca(m): 2,k: 1000,count: 167,i:400
# pca(m): 2,k: 1000,count: 172,i:410
# pca(m): 2,k: 1000,count: 176,i:420
# pca(m): 2,k: 1000,count: 179,i:430
# pca(m): 2,k: 1000,count: 182,i:440
# pca(m): 2,k: 1000,count: 188,i:450
# pca(m): 2,k: 1000,count: 193,i:460
# pca(m): 2,k: 1000,count: 198,i:470
# pca(m): 2,k: 1000,count: 205,i:480
# pca(m): 2,k: 1000,count: 209,i:490
# pca(m): 2,k: 1000,count: 213,i:500
# pca(m): 2,k: 1000,count: 216,i:510
# pca(m): 2,k: 1000,count: 222,i:520
# pca(m): 2,k: 1000,count: 228,i:530
# pca(m): 2,k: 1000,count: 234,i:540
# pca(m): 2,k: 1000,count: 239,i:550
# pca(m): 2,k: 1000,count: 244,i:560
# pca(m): 2,k: 1000,count: 250,i:570
# pca(m): 2,k: 1000,count: 254,i:580
# pca(m): 2,k: 1000,count: 258,i:590
# pca(m): 2,k: 1000,count: 266,i:600
# pca(m): 2,k: 1000,count: 269,i:610
# pca(m): 2,k: 1000,count: 271,i:620
# pca(m): 2,k: 1000,count: 276,i:630
# pca(m): 2,k: 1000,count: 284,i:640
# pca(m): 2,k: 1000,count: 286,i:650
# pca(m): 2,k: 1000,count: 290,i:660
# pca(m): 2,k: 1000,count: 298,i:670
# pca(m): 2,k: 1000,count: 303,i:680
# pca(m): 2,k: 1000,count: 311,i:690
# pca(m): 2,k: 1000,count: 316,i:700
# pca(m): 2,k: 1000,count: 317,i:710
# pca(m): 2,k: 1000,count: 320,i:720
# pca(m): 2,k: 1000,count: 323,i:730
# pca(m): 2,k: 1000,count: 327,i:740
# pca(m): 2,k: 1000,count: 332,i:750
# pca(m): 2,k: 1000,count: 337,i:760
# pca(m): 2,k: 1000,count: 341,i:770
# pca(m): 2,k: 1000,count: 346,i:780
# pca(m): 2,k: 1000,count: 351,i:790
# pca(m): 2,k: 1000,count: 355,i:800
# pca(m): 2,k: 1000,count: 359,i:810
# pca(m): 2,k: 1000,count: 366,i:820
# pca(m): 2,k: 1000,count: 372,i:830
# pca(m): 2,k: 1000,count: 377,i:840
# pca(m): 2,k: 1000,count: 383,i:850
# pca(m): 2,k: 1000,count: 388,i:860
# pca(m): 2,k: 1000,count: 389,i:870
# pca(m): 2,k: 1000,count: 392,i:880
# pca(m): 2,k: 1000,count: 395,i:890
# pca(m): 2,k: 1000,count: 400,i:900
# pca(m): 2,k: 1000,count: 403,i:910
# pca(m): 2,k: 1000,count: 406,i:920
# pca(m): 2,k: 1000,count: 414,i:930
# pca(m): 2,k: 1000,count: 420,i:940
# pca(m): 2,k: 1000,count: 424,i:950
# pca(m): 2,k: 1000,count: 429,i:960
# pca(m): 2,k: 1000,count: 437,i:970
# pca(m): 2,k: 1000,count: 443,i:980
# pca(m): 2,k: 1000,count: 450,i:990
# pca(m): 2,k: 1000,count: 454,i:1000
# pca(m): 2,k: 1000,count: 454
# pca(m): 50,k: 2,count: 0,i:0
# pca(m): 50,k: 2,count: 9,i:10
# pca(m): 50,k: 2,count: 16,i:20
# pca(m): 50,k: 2,count: 21,i:30
# pca(m): 50,k: 2,count: 27,i:40
# pca(m): 50,k: 2,count: 37,i:50
# pca(m): 50,k: 2,count: 42,i:60
# pca(m): 50,k: 2,count: 50,i:70
# pca(m): 50,k: 2,count: 59,i:80
# pca(m): 50,k: 2,count: 62,i:90
# pca(m): 50,k: 2,count: 71,i:100
# pca(m): 50,k: 2,count: 77,i:110
# pca(m): 50,k: 2,count: 84,i:120
# pca(m): 50,k: 2,count: 89,i:130
# pca(m): 50,k: 2,count: 94,i:140
# pca(m): 50,k: 2,count: 99,i:150
# pca(m): 50,k: 2,count: 108,i:160
# pca(m): 50,k: 2,count: 113,i:170
# pca(m): 50,k: 2,count: 119,i:180
# pca(m): 50,k: 2,count: 125,i:190
# pca(m): 50,k: 2,count: 133,i:200
# pca(m): 50,k: 2,count: 140,i:210
# pca(m): 50,k: 2,count: 147,i:220
# pca(m): 50,k: 2,count: 154,i:230
# pca(m): 50,k: 2,count: 160,i:240
# pca(m): 50,k: 2,count: 166,i:250
# pca(m): 50,k: 2,count: 171,i:260
# pca(m): 50,k: 2,count: 179,i:270
# pca(m): 50,k: 2,count: 185,i:280
# pca(m): 50,k: 2,count: 189,i:290
# pca(m): 50,k: 2,count: 194,i:300
# pca(m): 50,k: 2,count: 201,i:310
# pca(m): 50,k: 2,count: 209,i:320
# pca(m): 50,k: 2,count: 216,i:330
# pca(m): 50,k: 2,count: 222,i:340
# pca(m): 50,k: 2,count: 227,i:350
# pca(m): 50,k: 2,count: 234,i:360
# pca(m): 50,k: 2,count: 240,i:370
# pca(m): 50,k: 2,count: 243,i:380
# pca(m): 50,k: 2,count: 250,i:390
# pca(m): 50,k: 2,count: 256,i:400
# pca(m): 50,k: 2,count: 262,i:410
# pca(m): 50,k: 2,count: 268,i:420
# pca(m): 50,k: 2,count: 277,i:430
# pca(m): 50,k: 2,count: 282,i:440
# pca(m): 50,k: 2,count: 289,i:450
# pca(m): 50,k: 2,count: 296,i:460
# pca(m): 50,k: 2,count: 300,i:470
# pca(m): 50,k: 2,count: 307,i:480
# pca(m): 50,k: 2,count: 314,i:490
# pca(m): 50,k: 2,count: 322,i:500
# pca(m): 50,k: 2,count: 330,i:510
# pca(m): 50,k: 2,count: 337,i:520
# pca(m): 50,k: 2,count: 345,i:530
# pca(m): 50,k: 2,count: 350,i:540
# pca(m): 50,k: 2,count: 356,i:550
# pca(m): 50,k: 2,count: 364,i:560
# pca(m): 50,k: 2,count: 371,i:570
# pca(m): 50,k: 2,count: 379,i:580
# pca(m): 50,k: 2,count: 385,i:590
# pca(m): 50,k: 2,count: 392,i:600
# pca(m): 50,k: 2,count: 396,i:610
# pca(m): 50,k: 2,count: 405,i:620
# pca(m): 50,k: 2,count: 411,i:630
# pca(m): 50,k: 2,count: 419,i:640
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-40ec29dbe642> in <module>()
#      18             limit = 500
#      19         for i in range(limit+1):
# ---> 20             nei = obj.getNeighbours(x,reducedTest[i])
#      21             ans = obj.getClass(nei)
#      22 #             print("our ans: "+str(ans)+" ,original ans:"+str(Y_test[i])+" for i:"+str(i))
#
# <ipython-input-126-2f1ce2b68b6a> in getNeighbours(self, dataset, data)
#      32             ##change the below line for different distances
#      33 #             print("i in neighbour: "+str(i))
# ---> 34             dist = self.euclideanDistance(data,dataset[i],length)
#      35             distances.append((dataset[i],dist))
#      36         distances.sort(key=operator.itemgetter(1))
#
# KeyboardInterrupt:
